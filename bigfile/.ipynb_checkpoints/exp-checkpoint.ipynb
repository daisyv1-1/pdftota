# %%
import sys
print(sys.executable)
# Out:
# f:\pdftota\venv\Scripts\python.exe

# %%
import langchain

# %%
from langchain.document_loaders import TextLoader
from pypdf import PdfReader
from langchain import HuggingFaceHub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA, ConversationalRetrievalChain
from langchain.memory import ConversationBufferWindowMemory

# %%
doc1=''
reader = PdfReader('F:\pdftota\datasources\spyfam.pdf')
for page in reader.pages:
    doc1 += page.extract_text()

doc1[:300]
# Out:
# 'Spy × Family\nGenre Action[1]\nSpy comedy[2]\nAnime television series\nDirected byKazuhiro Furuhashi\nTakahiro Harada (S2)\nWritten by Kazuhiro Furuhashi (S1)\nIchirō Ōkouchi (S2)\nMusic by (K)now Name\nStudio Wit Studio\nCloverWorks\nLicensed byCrunchyroll\nSA/SEA:\n Muse\nCommunication\nOriginal\nnetworkTV Tokyo\n'

# %%
chunk_size = 200
chunk_overlap =  10

splitter = RecursiveCharacterTextSplitter(
    chunk_size = chunk_size,
    chunk_overlap =  chunk_overlap
)

split1= splitter.split_text(doc1)
split1= splitter.create_documents(doc1)

# %% [markdown]
# ## document 2

# %%
loader = TextLoader("F:/pdftota/datasources/Bird.txt", encoding = 'utf-8')
loader = loader.load()
doc2 = loader[0]
doc2 = str(doc2)
doc2
# Out:
# 'page_content=\'Bird\\n\\n\\nBirds are a group of warm-blooded vertebrates\\n\\n\\n\\n\\n\\nBirds\\n\\n\\nconstituting the class Aves (/ˈeɪviːz/), characterised by Temporal range:\\n\\nfeathers, toothless beaked jaws, the laying of hard-\\n\\nPossible Early Cretaceous or early Late\\n\\nshelled eggs, a high metabolic rate, a four-chambered Cretaceous origin based on molecular\\n\\nheart, and a strong yet lightweight skeleton. Birds live worldwide and range in size from the 5.5 cm (2.2 in)\\n\\nclock[3][4][5]\\n\\nbee hummingbird to the 2.8 m (9 ft 2 in) common\\n\\nostrich. There are over 11,000 living species, more than\\n\\nhalf of which are passerine, or "perching" birds. Birds\\n\\nhave wings whose development varies according to\\n\\nspecies; the only known groups without wings are the\\n\\nextinct moa and elephant birds. Wings, which are modified forelimbs, gave birds the ability to fly,\\n\\nalthough further evolution has led to the loss of flight in\\n\\nsome birds, including ratites, penguins, and diverse\\n\\nendemic island species. The digestive and respiratory\\n\\nsystems of birds are also uniquely adapted for flight.\\n\\nSome bird species of aquatic environments, particularly\\n\\nseabirds and some waterbirds, have further evolved for swimming. The study of birds is called ornithology.\\n\\nBirds are feathered theropod dinosaurs and constitute the only known living dinosaurs. Likewise, birds are\\n\\nconsidered reptiles in the modern cladistic sense of the term, and their closest living relatives are the\\n\\ncrocodilians. Birds are descendants of the primitive\\n\\navialans (whose members include Archaeopteryx)\\n\\nScientific classification\\n\\nwhich first appeared during the Late Jurassic.\\n\\nAccording to recent estimates, modern birds\\n\\nDomain:\\n\\nEukaryota\\n\\n(Neornithes) evolved in the Late Cretaceous and\\n\\nKingdom:\\n\\nAnimalia\\n\\ndiversified dramatically around the time of the\\n\\nPhylum:\\n\\nChordata\\n\\nCretaceous–Paleogene extinction event 66 million\\n\\nyears ago, which killed off the pterosaurs and all non-\\n\\nClade:\\n\\nSauropsida\\n\\navian dinosaurs.[7]\\n\\nClade:\\n\\nArchosauria\\n\\nMany social species pass on knowledge across\\n\\nClade:\\n\\nAvemetatarsalia\\n\\ngenerations, which is considered a form of culture.\\n\\nClade:\\n\\nDinosauria\\n\\nBirds are social, communicating with visual signals,\\n\\nClade:\\n\\nTheropoda\\n\\ncalls, and songs, and participating in such behaviours as\\n\\ncooperative breeding and hunting, flocking, and Clade:\\n\\nOrnithurae\\n\\nmobbing of predators. The vast majority of bird species\\n\\n\\n\\nare socially (but not necessarily sexually) monogamous,\\n\\nClass:\\n\\nAves\\n\\nusually for one breeding season at a time, sometimes\\n\\nLinnaeus, 1758[6]\\n\\nfor years, and rarely for life. Other species have\\n\\nExtant clades\\n\\nbreeding systems that are polygynous (one male with\\n\\nmany females) or, rarely, polyandrous (one female with\\n\\nPalaeognathae (ratites and tinamou)\\n\\nmany males). Birds produce offspring by laying eggs\\n\\nwhich are fertilised through sexual reproduction. They\\n\\nStruthionimorphae (ostrich)\\n\\nare usually laid in a nest and incubated by the parents.\\n\\nNotopalaeognathae\\n\\nMost birds have an extended period of parental care\\n\\nafter hatching.\\n\\nNeognathae\\n\\nMany species of birds are economically important as\\n\\nPangalloanserae (fowl)\\n\\nfood for human consumption and raw material in\\n\\nNeoaves\\n\\nmanufacturing, with domesticated and undomesticated\\n\\nbirds being important sources of eggs, meat, and\\n\\nSynonyms\\n\\nfeathers. Songbirds, parrots, and other species are\\n\\nNeornithes Gadow, 1883\\n\\npopular as pets. Guano (bird excrement) is harvested\\n\\nfor use as a fertiliser. Birds figure throughout human\\n\\nculture. About 120 to 130 species have become extinct due to human activity since the 17th century, and hundreds more before then. Human activity threatens abo ...

# %%
split2 = splitter.split_text(doc2)
split2 = splitter.create_documents(doc2)

# %% [markdown]
# ## embedding

# %%
import platform

# Get the processor information
processor = platform.processor()
print(f"Processor: {processor}")
# Out:
# Processor: Intel64 Family 6 Model 78 Stepping 3, GenuineIntel

# %%
instructor_embeddings = HuggingFaceInstructEmbeddings(model_name  ="hkunlp/instructor-xl", model_kwargs ={})


db = FAISS.from_documents?
# Out:
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 instructor_embeddings = HuggingFaceInstructEmbeddings(model_name  ="hkunlp/instructor-xl", model_kwargs ={})
#       4 get_ipython().run_line_magic('pinfo', 'FAISS.from_documents')
#
# File f:\pdftota\venv\Lib\site-packages\langchain_community\embeddings\huggingface.py:167, in HuggingFaceInstructEmbeddings.__init__(self, **kwargs)
#     164 try:
#     165     from InstructorEmbedding import INSTRUCTOR
# --> 167     self.client = INSTRUCTOR(
#     168         self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#     169     )
#     170 except ImportError as e:
#     171     raise ImportError("Dependencies for InstructorEmbedding not found.") from e
#
# File f:\pdftota\venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:87, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, cache_folder, use_auth_token)
#      83     model_path = os.path.join(cache_folder, model_name_or_path.replace("/", "_"))
#      85     if not os.path.exists(os.path.join(model_path, 'modules.json')):
#      86         # Download from hub with caching
# ---> 87         snapshot_download(model_name_or_path,
#      88                             cache_dir=cache_folder,
#      89                             library_name='sentence-transformers',
#      90                             library_version=__version__,
#      91                             ignore_files=['flax_model.msgpack', 'rust_model.ot', 'tf_model.h5'],
#      92                             use_auth_token=use_auth_token)
#      94 if os.path.exists(os.path.join(model_path, 'modules.json')):    #Load as SentenceTransformer model
#      95     modules = self._load_sbert_model(model_path)
#
# File f:\pdftota\venv\Lib\site-packages\sentence_transformers\util.py:491, in snapshot_download(repo_id, revision, cache_dir, library_name, library_version, user_agent, ignore_files, use_auth_token)
#     486 if version.parse(huggingface_hub.__version__) >= version.parse("0.8.1"):
#     487     # huggingface_hub v0.8.1 introduces a new cache layout. We sill use a manual layout
#     488     # And need to pass legacy_cache_layout=True to avoid that a warning will be printed
#     489     cached_download_args['legacy_cache_layout'] = True
# --> 491 path = cached_download(**cached_download_args)
#     493 if os.path.exists(path + ".lock"):
#     494     os.remove(path + ".lock")
#
# File f:\pdftota\venv\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File f:\pdftota\venv\Lib\site-packages\huggingface_hub\file_download.py:798, in cached_download(url, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#     795     cache_path = "\\\\?\\" + os.path.abspath(cache_path)
#     797 with WeakFileLock(lock_path):
# --> 798     _download_to_tmp_and_move(
#     799         incomplete_path=Path(cache_path + ".incomplete"),
#     800         destination_path=Path(cache_path),
#     801         url_to_download=url_to_download,
#     802         proxies=proxies,
#     803         headers=headers,
#     804         expected_size=expected_size,
#     805         filename=filename,
#     806         force_download=force_download,
#     807     )
#     809     if force_filename is None:
#     810         logger.info("creating metadata file for %s", cache_path)
#
# File f:\pdftota\venv\Lib\site-packages\huggingface_hub\file_download.py:1884, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1881         _check_disk_space(expected_size, incomplete_path.parent)
#    1882         _check_disk_space(expected_size, destination_path.parent)
# -> 1884     http_get(
#    1885         url_to_download,
#    1886         f,
#    1887         proxies=proxies,
#    1888         resume_size=resume_size,
#    1889         headers=headers,
#    1890         expected_size=expected_size,
#    1891     )
#    1893 logger.info(f"Download complete. Moving file to {destination_path}")
#    1894 _chmod_and_move(incomplete_path, destination_path)
#
# File f:\pdftota\venv\Lib\site-packages\huggingface_hub\file_download.py:539, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     537 new_resume_size = resume_size
#     538 try:
# --> 539     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     540         if chunk:  # filter out keep-alive new chunks
#     541             progress.update(len(chunk))
#
# File f:\pdftota\venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File f:\pdftota\venv\Lib\site-packages\urllib3\response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File f:\pdftota\venv\Lib\site-packages\urllib3\response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File f:\pdftota\venv\Lib\site-packages\urllib3\response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File f:\pdftota\venv\Lib\site-packages\urllib3\response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
